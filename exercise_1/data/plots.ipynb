# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
openMP = pd.read_csv("openMP.csv")

openMP
# Out:
#    size  steps  evolution  processor number  thread number  total time  \
# 0  1000   1000          1                 1              1    72635616
# 1  1000   1000          1                 1              2    36536630
# 2  1000   1000          1                 1              4    18318647
# 3  1000   1000          1                 1              8     9218737
# 4  1000   1000          1                 1             16     4652385
# 5  1000   1000          1                 1             32     2367646
# 6  1000   1000          1                 1             64     1302963
#
#    evolution time  average propagation time
# 0        72632154                         7
# 1        36534854                         7
# 2        18317337                         7
# 3         9217823                        15
# 4         4651514                        19
# 5         2366288                        21
# 6         1300866                        24

# %%
fig, ax = plt.subplots(figsize=(9, 4))

ax.plot(openMP["thread number"],openMP["evolution time"]/10**6)
ax.set_xlabel("number of threads")
ax.set_ylabel("time (seconds)")
ax.set_title("OpenMP scalability")
ax.set_xticks(openMP["thread number"])

# %%
openMP["evolution time"]/10**6
# Out:
# 0    72.632154
# 1    36.534854
# 2    18.317337
# 3     9.217823
# 4     4.651514
# 5     2.366288
# 6     1.300866
# Name: evolution time, dtype: float64

# %%
sMPI = pd.read_csv("strongMPI.csv")

sMPI
# Out:
#    size  steps  evolution  processor number  thread number  total time  \
# 0  1920   1000          1                 1             64   247556594
# 1  1920   1000          1                 2             64   125833415
# 2  1920   1000          1                 4             64    63860569
#
#    evolution time  average propagation time
# 0       247540577                        26
# 1       125822970                        46
# 2        63848344                       157

# %%
fig, ax = plt.subplots(figsize=(6,6))

ax.plot(sMPI["processor number"], sMPI["evolution time"]/10**6)
ax.set_xlabel("number of processors")
ax.set_ylabel("time (seconds)")
ax.set_title("Strong MPI scalability")
ax.set_xticks(sMPI["processor number"])

# %%
wMPI = pd.read_csv("weakMPI.csv")

wMPI
# Out:
#    size  steps  evolution  processor number  thread number  total time  \
# 0   100   1000          1                 1             64     1912650
# 1   200   1000          1                 4             64    77035128
#
#    evolution time  average propagation time
# 0         1908870                         1
# 1        77023156                     72181

# %%
fig, ax = plt.subplots(figsize=(7,6))

ax.plot(wMPI["processor number"], wMPI["average propagation time"])
ax.set_xlabel("number of processors")
ax.set_ylabel("time (microseconds)")
ax.set_title("Weak MPI scalability")
ax.set_xticks(wMPI["processor number"])
